671230704298677, 6.665855377822986, 6.660558887546516, 6.6553381028897824, 6.650190020464206, 6.645111758902963, 6.64010055390193, 6.635153753462195, 6.630268813325885, 6.625443292597513, 6.620674849543224, 6.615961237560839, 6.611300301313613, 6.606689973021173, 6.602128268901157, 6.597613285755482, 6.593143197695357, 6.5887162529993555, 6.584330771099283, 6.579985139688374, 6.575677811947184, 6.5714073038821015, 6.567172191772105, 6.562971109719211, 6.558802747298573, 6.554665847303971, 6.550559203585009, 6.546481658972162, 6.542432103286217, 6.538409471428506, 6.534412741548852, 6.530440933287911, 6.526493106090995, 6.522568357590372, 6.5186658220533396, 6.514784668893358, 6.51092410124176, 6.507083354577335, 6.5032616954118305, 6.499458420028677, 6.495672853273154, 6.491904347391534, 6.488152280917566, 6.484416057604135, 6.480695105398337, 6.476988875458256, 6.473296841209646, 6.469618497440979, 6.46595335943525, 6.462300962137134, 6.458660859353863, 6.455032622988708, 6.4514158423 ...

# %%
plt.figure(figsize=(12,6))
plt.plot(xs, ys, 'g+', label = 'original')
plt.plot(xs, GD[2], 'b.', label = 'final_prediction')
plt.title('Original vs Final prediction after Gradient Descent')
plt.legend(loc = "lower right")
plt.show()

# %% [markdown]
# This trained model is showing vast improvements after it’s full training cycle. We can examine further by inspecting its final predicted coefficients $a$, $b$ and $c$.

# %%
print(f"Final Coefficients predicted: {GD[1]}")
print(f"Original Coefficients: {coeffs}")
# Out:
# Final Coefficients predicted: (0.9996916669295112, -0.000612277642298992, 0.00825053009045484)
# Original Coefficients: [1, 0, 0]

# %% [markdown]
# Not too far off! A big improvement over the initial random model. Looking at the plot of the loss reduction over training offers further insights.

# %%
plt.figure(figsize=(12, 6))
plt.plot(GD[3], 'b-', label = 'loss')
# plt.xlim(0,50)
plt.title('Loss over 500 iterations')
plt.legend(loc="lower right")
plt.xlabel('Iterations')
plt.ylabel('MSE')
plt.show()

# %% [markdown]
# We observe that the model loss reached close to zero, to give us our more accurate coefficients. We can also see there was no major improvement in loss after about 100 epochs. An alternative strategy would be to add some kind of condition to the training step that stops training when a certain minimum loss threshold has been reached. This would prevent excessive training and potential over-fitting for the model.

# %% [markdown]
# # Things to try
#
#
#
# 1.   Change the coefficients array and try a different polynomial instead of our $x^2$.
#
# 2.   Increase/decrease the learning rate to see how many iterations will be take to coverge. Does it even converge on a huge learning rate?
# 3. Take a degree 5 polynomial with 5 roots and try different initializations, instead of random ones. Does it converge on different values for different initializations? Why does initialization not matter in our case of $x^2$?
# 4. Can you modify the algorithm to find a maxima of a function, instead of a minima?

# %%
#1.   Change the coefficients array and try a different polynomial instead of our $x^2$.

new_coeffs_cubic = [1, -2, 0, 1]

hundred_xs_cubic=np.random.uniform(-10,10,100)
ys_cubic=[eval_2nd_degree(new_coeffs_cubic,x) for x in hundred_xs_cubic]

plt.figure(figsize=(12, 6))
plt.scatter(hundred_xs_cubic, ys_cubic, label='cubic Polynomial')
plt.plot(hundred_xs_cubic,ys_cubic,label='cubic polynomial fit')
plt.title('data generated for cubic Polynomial')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
#2.   Increase/decrease the learning rate to see how many iterations will be take to coverge. Does it even converge on a huge learning rate?
def gradient_descent_with_lr(epochs, lr):

    losses = []
    rand_coeffs_to_test = rand_coeffs
    for i in range(epochs):
        loss = calc_gradient_2nd_poly_for_GD(rand_coeffs_to_test, hundred_xs, ys, lr)
        rand_coeffs_to_test = loss[1]
        losses.append(loss[0])

    return loss[0], loss[1], loss[2], losses

learning_rates = [0.1, 0.01, 0.001, 0.0001]
results = {}
for lr in learning_rates:
    result = gradient_descent_with_lr(1000, lr)
    results[lr] = result

plt.figure(figsize=(12, 6))
for lr, result in results.items():
    plt.plot(result[3], label=f'LR = {lr}')

plt.title('Loss Updates Over Iterations for Different Learning Rates')
plt.xlabel('Iterations')
plt.ylabel('Model Loss')
plt.legend()
plt.show()
# Out:
# <ipython-input-21-3e15a3826a00>:12: RuntimeWarning: overflow encountered in multiply
#   return sum((ys - y_bar) * (ys - y_bar)) / len(ys)
# <ipython-input-27-bad7532be911>:22: RuntimeWarning: overflow encountered in double_scalars
#   partial_a = x_squared * (y - y_bar)
# <ipython-input-27-bad7532be911>:32: RuntimeWarning: overflow encountered in double_scalars
#   gradient_a = (-2 / n) * sum(a_s)
# <ipython-input-27-bad7532be911>:33: RuntimeWarning: invalid value encountered in double_scalars
#   gradient_b = (-2 / n) * sum(b_s)
# <ipython-input-27-bad7532be911>:37: RuntimeWarning: invalid value encountered in double_scalars
#   a_new = coeffs[0] - lr * gradient_a
# <ipython-input-21-3e15a3826a00>:12: RuntimeWarning: overflow encountered in double_scalars
#   return sum((ys - y_bar) * (ys - y_bar)) / len(ys)

# %%
#3. Take a degree 5 polynomial with 5 roots and try different initializations, instead of random ones. Does it converge on different values for different initializations? Why does initialization not matter in our case of $x^2$?
new_coeffs_degree_5 = np.roots([1, -10, 35, -50, 24, -4])
hundred_xs_degree_5 = np.random.uniform(-5, 5, 100)
ys_degree_5 = [eval_2nd_degree(new_coeffs_degree_5, x) for x in hundred_xs_degree_5]

plt.figure(figsize=(12, 6))
plt.scatter(hundred_xs_degree_5, ys_degree_5, label='Degree 5 Polynomial')
plt.title('Data generated using a Degree 5 Polynomial')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/collections.py:192: ComplexWarning: Casting complex values to real discards the imaginary part
#   offsets = np.asanyarray(offsets, float)

# %% [markdown]
# initialization significantly influences convergence in a degree 5 polynomial due to complex landscapes. contrastingly the simplicity of x^2 results in consistent convergence , irrespective of initialization

# %%
#4. Can you modify the algorithm to find a maxima of a function, instead of a minima?

a_new_max =rand_coeffs[0]+lr*calc_grad[0]
b_new_max = rand_coeffs[1]+lr*calc_grad[1]
c_new_max = rand_coeffs[2]+lr*calc_grad[2]

new_model_coeffs_max=(a_new_max,b_new_max,c_new_max)
new_y_bar_max = eval_2nd_degree(new_model_coeffs_max,hundred_xs)
updated_model_loss_max = loss_mse(ys,new_y_bar_max)

print(f"its larger model loss:{updated_model_loss_max }  vs {initial_model_loss}")
# Out:
# its larger model loss:36399.18742687005  vs 18093.802965444087
