# %%
IMPLEMENTATION OF THE CUSTOMER COUNT

# %% [markdown]
# DATASET : ONE VIDEO
#
# https://mega.nz/file/wsEmmSKD#c3hl49wa37UPLKErehPNhp1CkV_ntf1R1WUeHjaXyRo

# %%
import cv2
from tracker import *
import pandas as pd
import numpy as np
import math
from ultralytics import YOLO

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\KanugulBharath Kumar\Downloads\peoplecounteryolov8-main\peoplecounteryolov8-main

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'coco.txt', 'coffee shop people count maintainance.ipynb', 'download.txt', 'main.py', 'peoplecount1', 'peoplecount1.mp4', 'tracker.py', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2-Copy1.ipynb', 'yolov8s.pt', '__pycache__']

# %%
tracker = projection()

model = YOLO('yolov8s.pt')

area1 = [(312, 388),(289, 390),(474, 469),(497, 462)]
area2 = [(279, 392),(250,397) ,(423,477),(454, 469)]


def RGB(event, x, y, flags, param):
    
    if event == cv2.EVENT_MOUSEMOVE:
        colorsBGR = [x, y]
        print(colorsBGR)


cv2.namedWindow('RGB')
cv2.setMouseCallback('RGB', RGB)

cap = cv2.VideoCapture('peoplecount1.mp4')

my_file = open("coco.txt", "r")
data = my_file.read()
class_list = data.split("\n")

count = 0

people_entering = {}
people_exiting = {}
entering = set()
exiting = set()

while True:
    ret, frame = cap.read()
    if not ret:
        break
    count += 1
    if count % 2 != 0:
        continue
    frame = cv2.resize(frame, (1020, 500))
    results = model.predict(frame)
    a = results[0].boxes.data
    px = pd.DataFrame(a).astype("float")
    list = []

    for index, row in px.iterrows():
        x1 = int(row[0])
        y1 = int(row[1])
        x2 = int(row[2])
        y2 = int(row[3])
        d = int(row[5])
        c = class_list[d]
        if 'person' in c:
            list.append([x1, y1, x2, y2])
    bbox_id = tracker.update(list)
    for bbox in bbox_id:
        x3, y3, x4, y4, id = bbox

        # into the hotel
        result = cv2.pointPolygonTest(np.array(area2, np.int32), ((x4, y4)), False)
        if result >= 0:
            people_entering[id] = (x4, y4)
            cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 0, 255), 2)
        if id in people_entering:
            result1 = cv2.pointPolygonTest(np.array(area1, np.int32), ((x4, y4)), False)
            if result1 >= 0:
                cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 255, 0), 2)
                cv2.circle(frame, (x4, y4), 5, (255, 0, 255), -1)
                cv2.putText(frame, str(id), (x3, y3), cv2.FONT_HERSHEY_COMPLEX, (0.5), (255, 255, 255), 1)
                entering.add(id)

    #out of hotel
        result2 = cv2.pointPolygonTest(np.array(area1, np.int32), ((x4, y4)), False)
        if result2 >= 0:
            people_exiting[id] = (x4, y4)
            cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 255, 0), 2)
        if id in people_exiting:
            result3 = cv2.pointPolygonTest(np.array(area2, np.int32), ((x4, y4)), False)
            if result3 >= 0:
                cv2.rectangle(frame, (x3, y3), (x4, y4), (255, 0, 0), 2)
                cv2.circle(frame, (x4, y4), 5, (255, 0, 255), -1)
                cv2.putText(frame, str(id), (x3, y3), cv2.FONT_HERSHEY_COMPLEX, (0.5), (255, 255, 255), 1)
                exiting.add(id)

    cv2.polylines(frame, [np.array(area1, np.int32)], True, (255, 0, 0), 2)
    cv2.putText(frame, str('entryROI'), (504, 471), cv2.FONT_HERSHEY_COMPLEX, (0.5), (0, 0, 0), 1)

    cv2.polylines(frame, [np.array(area2, np.int32)], True, (255, 0, 0), 2)
    cv2.putText(frame, str('exitROI'), (466, 485), cv2.FONT_HERSHEY_COMPLEX, (0.5), (0, 0, 0), 1)
    cv2.putText(frame, "THE COFFEE SHOP", (20, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 255, 255), 2)

    print(len(entering))
    print(len(exiting))
    ccc=len(entering)
    vvv=len(exiting)
    ccc1=ccc-vvv
    cv2.putText(frame, str('Current customer count:'), (40, 120), cv2.FONT_HERSHEY_COMPLEX, (0.8), (0, 255, 255), 3)
    #cv2.putText(frame, str('Max capacity:4'), (40,147), cv2.FONT_HERSHEY_COMPLEX, (0.8), (0, 255, 255), 3)
    if ccc1>=4:
        cv2.putText(frame, str(ccc1), (80, 160), cv2.FONT_HERSHEY_COMPLEX, (0.8), (0, 0, 255), 3)
    
    else:    
        cv2.putText(frame, str(ccc1), (80, 160), cv2.FONT_HERSHEY_COMPLEX, (0.8), (255, 0, 255), 3)
    #cv2.putText(frame, str('Max capacity:4'), (40,147), cv2.FONT_HERSHEY_COMPLEX, (0.8), (0, 255, 255), 3)


    cv2.imshow("window", frame)
    if cv2.waitKey(1) & 0xFF == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 320x640
ms preprocess, 126.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 121.6ms
# Speed: 2.0ms preprocess, 121.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 99.7ms
# Speed: 2.0ms preprocess, 99.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 144.0ms
# Speed: 1.0ms preprocess, 144.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 137.6ms
# Speed: 2.0ms preprocess, 137.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 110.5ms
# Speed: 1.0ms preprocess, 110.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 136.9ms
# Speed: 1.9ms preprocess, 136.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 113.8ms
# Speed: 0.0ms preprocess, 113.8ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 145.6ms
# Speed: 0.0ms preprocess, 145.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 144.3ms
# Speed: 0.0ms preprocess, 144.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 122.4ms
# Speed: 1.0ms preprocess, 122.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 142.0ms
# Speed: 0.0ms preprocess, 142.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 111.7ms
# Speed: 2.0ms preprocess, 111.7ms inference, 15.7ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 143.8ms
# Speed: 1.1ms preprocess, 143.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 146.3ms
# Speed: 2.0ms preprocess, 146.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 141.7ms
# Speed: 2.0ms preprocess, 141.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 130.0ms
# Speed: 2.4ms preprocess, 130.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 146.6ms
# Speed: 2.0ms preprocess, 146.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 116.0ms
# Speed: 1.9ms preprocess, 116.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 134.0ms
# Speed: 0.0ms preprocess, 134.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 145.7ms
# Speed: 16.6ms preprocess, 145.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 140.9ms
# Speed: 2.0ms preprocess, 140.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 124.6ms
# Speed: 2.0ms preprocess, 124.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 106.9ms
# Speed: 1.0ms preprocess, 106.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 134.3ms
# Speed: 2.0ms preprocess, 134.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 133.8ms
# Speed: 2.0ms preprocess, 133.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 130.2ms
# Speed: 2.4ms preprocess, 130.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 133.8ms
# Speed: 1.0ms preprocess, 133.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 141.3ms
# Speed: 0.0ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 131.4ms
# Speed: 2.0ms preprocess, 131.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 1 car, 117.2ms
# Speed: 1.0ms preprocess, 117.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 142.1ms
# Speed: 0.0ms preprocess, 142.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 144.0ms
# Speed: 0.0ms preprocess, 144.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 138.6ms
# Speed: 1.0ms preprocess, 138.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 93.3ms
# Speed: 1.0ms preprocess, 93.3ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 3 persons, 127.6ms
# Speed: 3.1ms preprocess, 127.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 129.6ms
# Speed: 14.0ms preprocess, 129.6ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 116.3ms
# Speed: 1.0ms preprocess, 116.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 124.2ms
# Speed: 1.0ms preprocess, 124.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 129.4ms
# Speed: 1.9ms preprocess, 129.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 126.0ms
# Speed: 1.0ms preprocess, 126.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 142.2ms
# Speed: 0.0ms preprocess, 142.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 135.9ms
# Speed: 1.0ms preprocess, 135.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 3 persons, 111.5ms
# Speed: 1.9ms preprocess, 111.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 129.2ms
# Speed: 1.0ms preprocess, 129.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 104.8ms
# Speed: 1.0ms preprocess, 104.8ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 146.1ms
# Speed: 1.0ms preprocess, 146.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 127.0ms
# Speed: 1.5ms preprocess, 127.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 143.1ms
# Speed: 0.0ms preprocess, 143.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 142.6ms
# Speed: 2.0ms preprocess, 142.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 141.3ms
# Speed: 2.6ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 143.6ms
# Speed: 1.0ms preprocess, 143.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 1 backpack, 131.8ms
# Speed: 1.0ms preprocess, 131.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 135.8ms
# Speed: 2.0ms preprocess, 135.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 1 backpack, 144.2ms
# Speed: 0.0ms preprocess, 144.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 1 backpack, 136.2ms
# Speed: 1.0ms preprocess, 136.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 backpack, 95.9ms
# Speed: 2.0ms preprocess, 95.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 1 backpack, 139.1ms
# Speed: 1.0ms preprocess, 139.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 1 backpack, 132.8ms
# Speed: 2.0ms preprocess, 132.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 1 backpack, 141.0ms
# Speed: 2.0ms preprocess, 141.0ms inference, 12.6ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 backpack, 134.3ms
# Speed: 15.7ms preprocess, 134.3ms inference, 16.5ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 car, 1 backpack, 125.0ms
# Speed: 2.0ms preprocess, 125.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 3 persons, 1 car, 164.4ms
# Speed: 0.0ms preprocess, 164.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 car, 1 handbag, 151.4ms
# Speed: 2.6ms preprocess, 151.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 car, 2 handbags, 138.2ms
# Speed: 1.0ms preprocess, 138.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 2 cars, 1 handbag, 146.4ms
# Speed: 1.5ms preprocess, 146.4ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 2 cars, 1 handbag, 127.4ms
# Speed: 1.0ms preprocess, 127.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 2 cars, 2 handbags, 115.6ms
# Speed: 1.0ms preprocess, 115.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 2 cars, 2 handbags, 133.4ms
# Speed: 1.0ms preprocess, 133.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 3 cars, 3 handbags, 128.8ms
# Speed: 1.0ms preprocess, 128.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 3 cars, 1 handbag, 130.4ms
# Speed: 2.0ms preprocess, 130.4ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 3 cars, 1 handbag, 129.9ms
# Speed: 0.0ms preprocess, 129.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 car, 1 handbag, 125.2ms
# Speed: 1.6ms preprocess, 125.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 car, 1 handbag, 145.7ms
# Speed: 13.5ms preprocess, 145.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 car, 2 handbags, 132.4ms
# Speed: 2.0ms preprocess, 132.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 3 cars, 140.8ms
# Speed: 2.8ms preprocess, 140.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 2 cars, 2 handbags, 119.0ms
# Speed: 1.0ms preprocess, 119.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 2 cars, 2 handbags, 137.4ms
# Speed: 2.0ms preprocess, 137.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 car, 2 handbags, 140.9ms
# Speed: 1.0ms preprocess, 140.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 2 handbags, 171.1ms
# Speed: 0.0ms preprocess, 171.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 handbag, 158.5ms
# Speed: 2.0ms preprocess, 158.5ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 164.8ms
# Speed: 0.0ms preprocess, 164.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 165.6ms
# Speed: 0.0ms preprocess, 165.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 tv, 115.0ms
# Speed: 1.0ms preprocess, 115.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 handbag, 110.5ms
# Speed: 0.0ms preprocess, 110.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 handbag, 145.6ms
# Speed: 0.0ms preprocess, 145.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 handbag, 122.7ms
# Speed: 2.0ms preprocess, 122.7ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 2 handbags, 164.1ms
# Speed: 2.0ms preprocess, 164.1ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 handbag, 132.2ms
# Speed: 2.0ms preprocess, 132.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 2 handbags, 142.8ms
# Speed: 0.0ms preprocess, 142.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 4 persons, 2 handbags, 1 tv, 148.2ms
# Speed: 0.0ms preprocess, 148.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 4 persons, 1 handbag, 145.0ms
# Speed: 2.0ms preprocess, 145.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 2 handbags, 129.0ms
# Speed: 1.0ms preprocess, 129.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 1 handbag, 117.8ms
# Speed: 1.0ms preprocess, 117.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 1 handbag, 111.2ms
# Speed: 2.0ms preprocess, 111.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 1 handbag, 108.5ms
# Speed: 2.0ms preprocess, 108.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 1 handbag, 1 refrigerator, 153.1ms
# Speed: 2.0ms preprocess, 153.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 1 handbag, 1 refrigerator, 132.1ms
# Speed: 2.0ms preprocess, 132.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 1 handbag, 134.9ms
# Speed: 2.0ms preprocess, 134.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 109.7ms
# Speed: 2.6ms preprocess, 109.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 132.5ms
# Speed: 0.0ms preprocess, 132.5ms inference, 11.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 1 handbag, 97.1ms
# Speed: 1.0ms preprocess, 97.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 1 handbag, 147.0ms
# Speed: 2.3ms preprocess, 147.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 1 handbag, 111.7ms
# Speed: 1.0ms preprocess, 111.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 126.8ms
# Speed: 2.0ms preprocess, 126.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 145.8ms
# Speed: 1.0ms preprocess, 145.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 1 handbag, 133.3ms
# Speed: 1.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 1 handbag, 153.7ms
# Speed: 2.0ms preprocess, 153.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 122.0ms
# Speed: 1.0ms preprocess, 122.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 145.8ms
# Speed: 1.0ms preprocess, 145.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 138.1ms
# Speed: 2.0ms preprocess, 138.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 134.2ms
# Speed: 2.0ms preprocess, 134.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 133.1ms
# Speed: 0.0ms preprocess, 133.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 137.3ms
# Speed: 1.0ms preprocess, 137.3ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 143.0ms
# Speed: 0.0ms preprocess, 143.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 1 person, 146.7ms
# Speed: 2.0ms preprocess, 146.7ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 1 person, 137.7ms
# Speed: 1.1ms preprocess, 137.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 1 person, 149.9ms
# Speed: 17.1ms preprocess, 149.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 1 person, 147.4ms
# Speed: 8.9ms preprocess, 147.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 1 person, 146.5ms
# Speed: 0.0ms preprocess, 146.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 1 person, 144.9ms
# Speed: 2.1ms preprocess, 144.9ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 134.8ms
# Speed: 2.0ms preprocess, 134.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 135.0ms
# Speed: 1.0ms preprocess, 135.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 130.0ms
# Speed: 0.0ms preprocess, 130.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 143.2ms
# Speed: 2.0ms preprocess, 143.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 138.1ms
# Speed: 2.0ms preprocess, 138.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 153.4ms
# Speed: 1.0ms preprocess, 153.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 152.3ms
# Speed: 0.0ms preprocess, 152.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 151.2ms
# Speed: 1.0ms preprocess, 151.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 133.8ms
# Speed: 1.9ms preprocess, 133.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 138.5ms
# Speed: 1.0ms preprocess, 138.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 151.7ms
# Speed: 1.8ms preprocess, 151.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 148.5ms
# Speed: 2.0ms preprocess, 148.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 147.9ms
# Speed: 0.0ms preprocess, 147.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 128.5ms
# Speed: 2.0ms preprocess, 128.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 141.1ms
# Speed: 2.0ms preprocess, 141.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 154.2ms
# Speed: 0.0ms preprocess, 154.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 151.5ms
# Speed: 1.0ms preprocess, 151.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 134.5ms
# Speed: 2.0ms preprocess, 134.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 129.0ms
# Speed: 1.6ms preprocess, 129.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 (no detections), 140.9ms
# Speed: 2.0ms preprocess, 140.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0

# %%
class projection:
    def __init__(self):
        self.center_points = {}
        self.id_count = 0


    def update(self, objects_rect):
        objects_bbs_ids = []

        for rect in objects_rect:
            x, y, w, h = rect
            cx = (x + x + w) // 2
            cy = (y + y + h) // 2

            same_object_detected = False
            for id, pt in self.center_points.items():
                dist = math.hypot(cx - pt[0], cy - pt[1])

                if dist < 35:
                    self.center_points[id] = (cx, cy)
                    objects_bbs_ids.append([x, y, w, h, id])
                    same_object_detected = True
                    break

            if same_object_detected is False:
                self.center_points[self.id_count] = (cx, cy)
                objects_bbs_ids.append([x, y, w, h, self.id_count])
                self.id_count += 1

        new_center_points = {}
        for obj_bb_id in objects_bbs_ids:
            _, _, _, _, object_id = obj_bb_id
            center = self.center_points[object_id]
            new_center_points[object_id] = center

        self.center_points = new_center_points.copy()
        return objects_bbs_ids
